# %%
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
dataset = pd.read_csv('carprice.csv')

# %%
dataset = dataset.dropna(axis=0)

# %%
dataset.columns
# Out:
# Index(['Car ID', 'Brand', 'Year', 'Engine Size', 'Fuel Type', 'Transmission',
#        'Mileage', 'Condition', 'Price', 'Model'],
#       dtype='object')

# %%
features = [ 'Year', 'Engine Size',
       'Mileage', ]

# %%
y = dataset.Price

# %%
X = dataset[features]

# %%
trainx, valx, trainy, valy = train_test_split(X, y, test_size=0.3, random_state=1)

# %%
model1 = DecisionTreeRegressor(random_state=1)

# %%
model1.fit(trainx,trainy)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
model2 = RandomForestRegressor(random_state=1)

# %%
model2.fit(trainx,trainy)
# Out:
# RandomForestRegressor(random_state=1)

# %%
model1pred=model1.predict(valx)

# %%
model2pred=model2.predict(valx)

# %%
predictions_df = pd.DataFrame({
    "Actual Price": valy.values,  # Use y_val (not trainx.Price)
    "Model1 Predicted": model1pred,
    "Model2 Predicted": model2pred
})

# %%
gpredictions_df.head()
# Out:
#    Actual Price  Model1 Predicted  Model2 Predicted
# 0      26632.41           8818.88        46105.8262
# 1      87853.95          60269.62        51743.1450
# 2      93288.11          64427.86        48211.1463
# 3      53092.73          96101.90        67267.3465
# 4      66779.18          57566.70        46258.1303
